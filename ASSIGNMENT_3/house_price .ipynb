# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### IMPORTING DATASET

# %%
dataset = pd.read_csv('housing price.csv')
dataset
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:,1].values

# %%
x
# Out:
# array([[1461],
#        [1462],
#        [1463],
#        ...,
#        [2917],
#        [2918],
#        [2919]], dtype=int64)

# %%
y
# Out:
# array([169277.0524984 , 187758.39398877, 183583.68356955, ...,
#        219222.42340006, 184924.279659  , 187741.86665748])

# %% [markdown]
# # DECISION TREE REGRESSION

# %%
# Fitting Decision Tree Regression to the dataset
from sklearn.tree import DecisionTreeRegressor
DTR = DecisionTreeRegressor(random_state = 0)
DTR.fit(x, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
# Predicting a new result
DTR_y_pred = DTR.predict(x_test)
print(DTR_y_pred)
# Out:
# [194255.56694889 180650.34241841 148217.26254065 158682.46001392
#  165281.2925974  175502.91810944 160172.72797397 211007.0082923
#  182675.20427059 175127.59621604 215911.67439033 190485.63407417
#  187992.45144475 147086.59893993 185157.83230552 183517.34369691
#  153346.2200863  167350.91082452 177294.83889774 172469.07159261
#  179555.21957079 156342.71758756 163481.50151972 158893.54306269
#  162582.28898128 168092.97548083 177133.70936185 190233.6091027
#  186711.71584808 200328.82279204 181922.15256011 164146.30603735
#  171289.39358176 196691.81930173 166548.31684976 194868.40989986
#  160387.6042639  183050.84625848 182084.79090195 180084.11894116
#  179436.70481018 181676.12655543 187720.35920717 163299.47798017
#  163784.61944086 180370.80862311 182694.49220982 189114.30378932
#  186570.12942178 183690.59599574 203840.87402131 181017.22245522
#  188000.82467959 166374.87986635 186581.83087869 186328.88004719
# ...

# %%
# Visualising the Decision Tree Regression results (higher resolution)
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
X_grid = np.arange(min(x), max(x), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(x, y, color = 'blue')
plt.plot(X_grid, DTR.predict(X_grid), color = 'pink')
plt.title('Housing Price Prediction (Training set)',fontsize=20)
plt.xlabel('Id',fontsize=18)
plt.ylabel('Saleprice',fontsize=18)
plt.show()

# %% [markdown]
# ## Accuracy

# %%
DTR_reg_acc=r2_score(y_test,DTR_y_pred)
print(r2_score(y_test,DTR_y_pred))
# Out:
# 1.0

# %% [markdown]
# ## Prediction

# %%
DTR.predict([[2900]])
# Out:
# array([183972.07105667])
